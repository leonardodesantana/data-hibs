# %%
import pandas as pd

# %%
#getting the data to be treated
pd.options.display.max_rows = 999
dfs = pd.read_csv('C:/data-hibs/data/FIFA_countries_db.csv')
dfs
# Out:
#        0                         1     2                    3     4  \
# 0   Code                   Country  Code              Country  Code
# 1    AFG               Afghanistan   GEO              Georgia   OMA
# 2    AIA                  Anguilla   GER              Germany   PAK
# 3    ALB                   Albania   GHA                Ghana   PAN
# 4    ALG                   Algeria   GIB            Gibraltar   PAR
# 5    AND                   Andorra   GNB        Guinea-Bissau   PER
# 6    ANG                    Angola   GRE               Greece   PHI
# 7    ARG                 Argentina   GRN              Grenada   PLE
# 8    ARM                   Armenia   GUA            Guatemala   PNG
# 9    ARU                     Aruba   GUI               Guinea   POL
# 10   ASA            American Samoa   GUM                 Guam   POR
# 11   ATG       Antigua and Barbuda   GUY               Guyana   PRK
# 12   AUS                 Australia   HAI                Haiti   PUR
# ...

# %%
#getting rid of the first row of the dataframe
dfs.drop(0)

#setting a new dataframe to work proper
df = pd.DataFrame({'Acronym' : dfs['0'], 
                   'Name' : dfs['1'],
                   'Acronym1': dfs['2'], 
                   'Name1': dfs['3'],
                  'Acronym2': dfs['4'],
                  'Name3': dfs['5']})

#wiping the first row (old column titles)
df.drop(0)
# Out:
#    Acronym                      Name Acronym1                Name1 Acronym2  \
# 1      AFG               Afghanistan      GEO              Georgia      OMA
# 2      AIA                  Anguilla      GER              Germany      PAK
# 3      ALB                   Albania      GHA                Ghana      PAN
# 4      ALG                   Algeria      GIB            Gibraltar      PAR
# 5      AND                   Andorra      GNB        Guinea-Bissau      PER
# 6      ANG                    Angola      GRE               Greece      PHI
# 7      ARG                 Argentina      GRN              Grenada      PLE
# 8      ARM                   Armenia      GUA            Guatemala      PNG
# 9      ARU                     Aruba      GUI               Guinea      POL
# 10     ASA            American Samoa      GUM                 Guam      POR
# 11     ATG       Antigua and Barbuda      GUY               Guyana      PRK
# ...

# %%
#creating a acronyms only dataframe
acronym = pd.DataFrame(df['Acronym'])
acronym1 = pd.DataFrame(df['Acronym1'])
acronym2 = pd.DataFrame(df['Acronym2'])

#cleaning unnecessary rows, rows_to_drop2
rows_to_drop = [0, 72]
rows_to_drop2 = [0,70,71,72]
acronym = acronym.drop(rows_to_drop)
acronym1 = acronym1.drop(rows_to_drop)
acronym2 = acronym2.drop(rows_to_drop2)

acronym.columns = ['Acronym']
acronym1.columns = ['Acronym']
acronym2. columns = ['Acronym']

# %%
combined_df = pd.concat([acronym, acronym1, acronym2], axis=0, ignore_index=True)
combined_df
# Out:
#     Acronym
# 0       AFG
# 1       AIA
# 2       ALB
# 3       ALG
# 4       AND
# 5       ANG
# 6       ARG
# 7       ARM
# 8       ARU
# 9       ASA
# 10      ATG
# 11      AUS
# 12      AUT
# 13      AZE
# 14      BAH
# 15      BAN
# 16      BDI
# 17      BEL
# 18      BEN
# 19      BER
# 20      BFA
# 21      BHR
# 22      BHU
# 23      BIH
# 24      BLR
# 25      BLZ
# 26      BOL
# 27      BOT
# 28      BRA
# 29      BRB
# 30      BRU
# 31      BUL
# 32      CAM
# 33      CAN
# 34      CAY
# 35      CGO
# 36      CHA
# 37      CHI
# 38      CHN
# 39      CIV
# 40      CMR
# 41      COD
# 42      COK
# 43      COL
# 44      COM
# 45      CPV
# 46      CRC
# 47      CRO
# 48      CTA
# 49      CUB
# 50      CUW
# 51      CYP
# 52      CZE
# 53      DEN
# 54      DJI
# 55      DMA
# 56      DOM
# 57      ECU
# 58      EGY
# 59      ENG
# 60      EQG
# 61      ERI
# 62      ESP
# 63      EST
# 64      ETH
# 65      FIJ
# 66      FIN
# 67      FRA
# 68      FRO
# 69      GAB
# ...
