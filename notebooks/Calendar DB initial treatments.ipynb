# %%
#importing needed libraries
import pandas as pd

# %%
#reading the raw .HTML db

data = pd.read_html('../raw data/calendar.html')

#making it into a pandas dataframe

df = pd.concat(data)
df
# Out:
#                Date   Time                              Opposition     TV  \
# 0         July 2021    NaN                                     NaN    NaN
# 1    Sat, 7/10/2021  15:00                           Civil Service  False
# 2    Wed, 7/14/2021  19:30                                Oostende  False
# 3    Sat, 7/17/2021  15:00                                 Cardiff  False
# 4    Thu, 7/22/2021  20:00  Paide Linnameeskond / GÅ¼ira United FC  False
# 5    Sun, 7/25/2021  15:00                              FC Utrecht  False
# 6    Thu, 7/29/2021  20:00  Paide Linnameeskond / GÅ¼ira United FC  False
# 7       August 2021    NaN                                     NaN    NaN
# 8     Sun, 8/1/2021  16:30                              Motherwell  False
# 9     Sun, 8/8/2021  15:00                             Ross County  False
# 10   Sun, 8/22/2021  13:00                                  Dundee  False
# 11   Sat, 8/28/2021  15:00                              Livingston  False
# ...

# %%
#getting rid of the 'Month Year' rows in the dataframe

df = df.dropna(subset=['Competition'])
df
# Out:
#                Date   Time                              Opposition     TV  \
# 1    Sat, 7/10/2021  15:00                           Civil Service  False
# 2    Wed, 7/14/2021  19:30                                Oostende  False
# 3    Sat, 7/17/2021  15:00                                 Cardiff  False
# 4    Thu, 7/22/2021  20:00  Paide Linnameeskond / GÅ¼ira United FC  False
# 5    Sun, 7/25/2021  15:00                              FC Utrecht  False
# 6    Thu, 7/29/2021  20:00  Paide Linnameeskond / GÅ¼ira United FC  False
# 8     Sun, 8/1/2021  16:30                              Motherwell  False
# 9     Sun, 8/8/2021  15:00                             Ross County  False
# 10   Sun, 8/22/2021  13:00                                  Dundee  False
# 11   Sat, 8/28/2021  15:00                              Livingston  False
# 13   Sun, 9/12/2021  13:00                                  Hearts  False
# 14   Sat, 9/18/2021  15:00                              St. Mirren  False
# ...

# %%
df.to_csv('../treated data/calendar.csv', index=False)
