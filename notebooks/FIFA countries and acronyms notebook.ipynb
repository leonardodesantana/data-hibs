# %%
#importing necessary libs
import pandas as pd1

# %%
#setting up the pandas dataframe
url = 'https://www.footballsquads.co.uk/fifacodes.htm'
dfs = pd.read_html(url)
df = pd.concat(dfs)
df
# Out:
#        0              1     2                 3     4         5
# 0   Code        Country  Code           Country  Code   Country
# 1    AFG    Afghanistan   GEO           Georgia   OMA      Oman
# 2    AIA       Anguilla   GER           Germany   PAK  Pakistan
# 3    ALB        Albania   GHA             Ghana   PAN    Panama
# 4    ALG        Algeria   GIB         Gibraltar   PAR  Paraguay
# ..   ...            ...   ...               ...   ...       ...
# 68   FRA         France   NIG             Niger   ZAM    Zambia
# 69   FRO  Faroe Islands   NIR  Northern Ireland   ZIM  Zimbabwe
# 70   GAB          Gabon   NOR            Norway   NaN       NaN
# 71   GAM         Gambia   NZL       New Zealand   NaN       NaN
# 72   NaN            NaN   NaN               NaN   NaN       NaN
#
# [73 rows x 6 columns]

# %%
#exporting the pandas DF to .csv
df.to_csv('C:\data-hibs\data\FIFA_countries_db.csv', index=False)
