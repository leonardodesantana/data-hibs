# %%
#getting the necessary libs
import pandas as pd

# %%
#turning the raw .HTML DB into a python object
data = pd.read_html('../raw data/training.html')

#now turning the object in a proper pandas dataframe
df = pd.concat(data)
df
# Out:
#          UID                  Name Trn Rat Workload          Focus  AtTa  \
# 0    5207982       Darren McGregor    7.45    Light            NaN   NaN
# 1    5217061       Lewis Stevenson    7.10    Light            NaN   NaN
# 2   28049656            Joe Newell    7.60    Light            NaN   NaN
# 3   28105523      Jake Doyle-Hayes       -    Light            NaN   NaN
# 4   29083920           Drey Wright    7.65    Light            NaN   NaN
# 5   29087736            Matt Macey    6.70    Light            NaN   NaN
# 6   29125333      Demetri Mitchell       -    Light            NaN   NaN
# 7   53151878           Runar Hauge       -    Light            NaN   NaN
# 8   53179963  Elias Hoff Melkersen       -    Light            NaN   NaN
# 9   61003672           Paul Hanlon    7.30    Light            NaN   NaN
# 10  61013783        David Mitchell       -    Light            NaN   NaN
# 11  61015863           Scott Allan    7.65    Light            NaN   NaN
# 12  61028791           Paul McGinn    7.25    Light            NaN   NaN
# 13  61066315          Chris Cadden    6.65    Light            NaN   NaN
# 14  61068991         Kyle Magennis    6.95    Light            NaN   NaN
# 15  61070818          Kevin Nisbet       -    Light            NaN   NaN
# 16  61077396         Ryan Porteous    7.00    Light            NaN   NaN
# 17  61093823             Josh Doig    7.65    Light            NaN   NaN
# 18  72051143         Chris Mueller       -    Light            NaN   NaN
# 19  74030889      Christian Doidge       -    Light            NaN   NaN
# 20  90086631         Josh Campbell    7.10    Light            NaN   NaN
# 21  96075402      Kevin DÄ
# browski    7.75    Light            NaN   NaN
# 22  61092645        Steven Bradley       -    Light            NaN   NaN
# 23  28116307          Harry Clarke       -    Light            NaN   NaN
# 24  36062516           Alex GogiÄ       -   Medium            NaN   NaN
# 25  28122192      Sylvester Jasper       -    Light            NaN   NaN
# 26  29179387        Ewan Henderson       -    Light            NaN   NaN
# 27  61078239           James Scott       -    Light            NaN   NaN
# 28    356951          Jamie Murphy       -   Medium            NaN   NaN
# 29  18102074         Rocky Bushiri       -   Medium  General Rehab   NaN
#
#     DeTe  Fit  GKH    GKS Level  Performance Physio Recommendation  \
# 0    NaN  NaN  NaN  False     -          NaN                     -
# 1    NaN  NaN  NaN  False     -          NaN                     -
# 2    NaN  NaN  NaN  False     -          NaN                     -
# 3    NaN  NaN  NaN  False     -          NaN                     -
# 4    NaN  NaN  NaN  False     -          NaN                     -
# 5    NaN  NaN  NaN  False     -          NaN                     -
# 6    NaN  NaN  NaN  False     -          NaN                     -
# 7    NaN  NaN  NaN  False     -          NaN                     -
# 8    NaN  NaN  NaN  False     -          NaN                     -
# 9    NaN  NaN  NaN  False     -          NaN                     -
# 10   NaN  NaN  NaN  False     -          NaN                     -
# 11   NaN  NaN  NaN  False     -          NaN                     -
# 12   NaN  NaN  NaN  False     -          NaN                     -
# 13   NaN  NaN  NaN  False     -          NaN                     -
# 14   NaN  NaN  NaN  False     -          NaN                     -
# 15   NaN  NaN  NaN  False     -          NaN                     -
# 16   NaN  NaN  NaN  False     -          NaN                     -
# 17   NaN  NaN  NaN  False     -          NaN                     -
# 18   NaN  NaN  NaN  False     -          NaN                     -
# 19   NaN  NaN  NaN  False     -          NaN                     -
# 20   NaN  NaN  NaN  False     -          NaN                     -
# 21   NaN  NaN  NaN  False     -          NaN                     -
# 22   NaN  NaN  NaN  False     -          NaN                   NaN
# 23   NaN  NaN  NaN  False     -          NaN                     -
# 24   NaN  NaN  NaN  False     -          NaN                   NaN
# 25   NaN  NaN  NaN  False     -          NaN                     -
# 26   NaN  NaN  NaN  False     -          NaN                     -
# 27   NaN  NaN  NaN  False     -          NaN                     -
# 28   NaN  NaN  NaN  False     -          NaN                   NaN
# 29   NaN  NaN  NaN  False     -          NaN                     -
#
#     New Player Trait         Position/Role/Duty  PoTa  PoTe  \
# 0                NaN   D (C) - Playing position   NaN   NaN
# 1                NaN   D (L) - Playing position   NaN   NaN
# 2                NaN   M (C) - Playing position   NaN   NaN
# 3                NaN   M (C) - Playing position   NaN   NaN
# 4                NaN  AM (R) - Playing position   NaN   NaN
# 5                NaN      GK - Playing position   NaN   NaN
# 6                NaN  AM (R) - Playing position   NaN   NaN
# 7                NaN  AM (R) - Playing position   NaN   NaN
# 8                NaN  ST (C) - Playing position   NaN   NaN
# 9                NaN   D (C) - Playing position   NaN   NaN
# 10               NaN      GK - Playing position   NaN   NaN
# 11               NaN   M (C) - Playing position   NaN   NaN
# 12               NaN   D (R) - Playing position   NaN   NaN
# 13               NaN   M (R) - Playing position   NaN   NaN
# 14               NaN   M (C) - Playing position   NaN   NaN
# 15               NaN  ST (C) - Playing position   NaN   NaN
# 16               NaN   D (C) - Playing position   NaN   NaN
# 17               NaN   D (L) - Playing position   NaN   NaN
# 18               NaN  AM (R) - Playing position   NaN   NaN
# 19               NaN  ST (C) - Playing position   NaN   NaN
# 20               NaN   M (C) - Playing position   NaN   NaN
# 21               NaN      GK - Playing position   NaN   NaN
# 22               NaN                        NaN   NaN   NaN
# 23               NaN   D (C) - Playing position   NaN   NaN
# 24               NaN                        NaN   NaN   NaN
# 25               NaN  AM (R) - Playing position   NaN   NaN
# 26               NaN   M (C) - Playing position   NaN   NaN
# 27               NaN  AM (L) - Playing position   NaN   NaN
# 28               NaN                        NaN   NaN   NaN
# 29               NaN   D (C) - Playing position   NaN   NaN
#
#                Training Happiness Training Happiness Details  \
# 0   Content with training overall                        NaN
# 1   Content with training overall                        NaN
# 2   Content with training overall                        NaN
# 3   Content with training overall                        NaN
# 4   Content with training overall                        NaN
# 5   Content with training overall                        NaN
# 6   Content with training overall                        NaN
# 7   Content with training overall                        NaN
# 8   Content with training overall                        NaN
# 9   Content with training overall                        NaN
# 10  Content with training overall                        NaN
# 11  Content with training overall                        NaN
# 12  Content with training overall                        NaN
# 13  Content with training overall                        NaN
# 14  Content with training overall                        NaN
# 15  Content with training overall                        NaN
# 16  Content with training overall                        NaN
# 17  Content with training overall                        NaN
# 18  Content with training overall                        NaN
# 19  Content with training overall                    Injured
# 20  Content with training overall                        NaN
# 21  Content with training overall                        NaN
# 22                              -                          -
# 23  Content with training overall                        NaN
# 24                              -                          -
# 25  Content with training overall                        NaN
# 26  Content with training overall                        NaN
# 27  Content with training overall                        NaN
# 28                              -                          -
# 29  Content with training overall                    Injured
#
#    Training Intensity
# 0    Normal Intensity
# 1    Normal Intensity
# 2    Normal Intensity
# 3    Normal Intensity
# 4    Normal Intensity
# 5    Normal Intensity
# 6    Normal Intensity
# 7    Normal Intensity
# 8    Normal Intensity
# 9    Normal Intensity
# 10   Normal Intensity
# 11   Normal Intensity
# 12   Normal Intensity
# 13   Normal Intensity
# 14   Normal Intensity
# 15                NaN
# 16   Normal Intensity
# 17   Normal Intensity
# 18   Normal Intensity
# 19                NaN
# 20   Normal Intensity
# 21   Normal Intensity
# 22                NaN
# 23   Normal Intensity
# 24                NaN
# 25   Normal Intensity
# 26   Normal Intensity
# 27   Normal Intensity
# 28                NaN
# 29                NaN

# %%
#getting a list of the dataframe structure
for col in df.columns:
    print("{}: {}".format(col,df[col].dtype))
# Out:
# UID: int64
# Name: object
# Trn Rat: object
# Workload: object
# Focus: object
# AtTa: float64
# DeTe: float64
# Fit: float64
# GKH: float64
# GKS: bool
# Level: object
# Performance: float64
# Physio Recommendation: object
# New Player Trait: float64
# Position/Role/Duty: object
# PoTa: float64
# PoTe: float64
# Training Happiness: object
# Training Happiness Details: object
# Training Intensity: object

# %%
#getting rid of the 'Name' column
column_to_drop = ['Name']

df.drop(columns=column_to_drop, inplace=True)
# Out:
#          UID Trn Rat Workload          Focus  AtTa  DeTe  Fit  GKH    GKS  \
# 0    5207982    7.45    Light            NaN   NaN   NaN  NaN  NaN  False
# 1    5217061    7.10    Light            NaN   NaN   NaN  NaN  NaN  False
# 2   28049656    7.60    Light            NaN   NaN   NaN  NaN  NaN  False
# 3   28105523       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 4   29083920    7.65    Light            NaN   NaN   NaN  NaN  NaN  False
# 5   29087736    6.70    Light            NaN   NaN   NaN  NaN  NaN  False
# 6   29125333       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 7   53151878       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 8   53179963       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 9   61003672    7.30    Light            NaN   NaN   NaN  NaN  NaN  False
# 10  61013783       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 11  61015863    7.65    Light            NaN   NaN   NaN  NaN  NaN  False
# 12  61028791    7.25    Light            NaN   NaN   NaN  NaN  NaN  False
# 13  61066315    6.65    Light            NaN   NaN   NaN  NaN  NaN  False
# 14  61068991    6.95    Light            NaN   NaN   NaN  NaN  NaN  False
# 15  61070818       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 16  61077396    7.00    Light            NaN   NaN   NaN  NaN  NaN  False
# 17  61093823    7.65    Light            NaN   NaN   NaN  NaN  NaN  False
# 18  72051143       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 19  74030889       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 20  90086631    7.10    Light            NaN   NaN   NaN  NaN  NaN  False
# 21  96075402    7.75    Light            NaN   NaN   NaN  NaN  NaN  False
# 22  61092645       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 23  28116307       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 24  36062516       -   Medium            NaN   NaN   NaN  NaN  NaN  False
# 25  28122192       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 26  29179387       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 27  61078239       -    Light            NaN   NaN   NaN  NaN  NaN  False
# 28    356951       -   Medium            NaN   NaN   NaN  NaN  NaN  False
# 29  18102074       -   Medium  General Rehab   NaN   NaN  NaN  NaN  False
#
#    Level  Performance Physio Recommendation  New Player Trait  \
# 0      -          NaN                     -               NaN
# 1      -          NaN                     -               NaN
# 2      -          NaN                     -               NaN
# 3      -          NaN                     -               NaN
# 4      -          NaN                     -               NaN
# 5      -          NaN                     -               NaN
# 6      -          NaN                     -               NaN
# 7      -          NaN                     -               NaN
# 8      -          NaN                     -               NaN
# 9      -          NaN                     -               NaN
# 10     -          NaN                     -               NaN
# 11     -          NaN                     -               NaN
# 12     -          NaN                     -               NaN
# 13     -          NaN                     -               NaN
# 14     -          NaN                     -               NaN
# 15     -          NaN                     -               NaN
# 16     -          NaN                     -               NaN
# 17     -          NaN                     -               NaN
# 18     -          NaN                     -               NaN
# 19     -          NaN                     -               NaN
# 20     -          NaN                     -               NaN
# 21     -          NaN                     -               NaN
# 22     -          NaN                   NaN               NaN
# 23     -          NaN                     -               NaN
# 24     -          NaN                   NaN               NaN
# 25     -          NaN                     -               NaN
# 26     -          NaN                     -               NaN
# 27     -          NaN                     -               NaN
# 28     -          NaN                   NaN               NaN
# 29     -          NaN                     -               NaN
#
#            Position/Role/Duty  PoTa  PoTe             Training Happiness  \
# 0    D (C) - Playing position   NaN   NaN  Content with training overall
# 1    D (L) - Playing position   NaN   NaN  Content with training overall
# 2    M (C) - Playing position   NaN   NaN  Content with training overall
# 3    M (C) - Playing position   NaN   NaN  Content with training overall
# 4   AM (R) - Playing position   NaN   NaN  Content with training overall
# 5       GK - Playing position   NaN   NaN  Content with training overall
# 6   AM (R) - Playing position   NaN   NaN  Content with training overall
# 7   AM (R) - Playing position   NaN   NaN  Content with training overall
# 8   ST (C) - Playing position   NaN   NaN  Content with training overall
# 9    D (C) - Playing position   NaN   NaN  Content with training overall
# 10      GK - Playing position   NaN   NaN  Content with training overall
# 11   M (C) - Playing position   NaN   NaN  Content with training overall
# 12   D (R) - Playing position   NaN   NaN  Content with training overall
# 13   M (R) - Playing position   NaN   NaN  Content with training overall
# 14   M (C) - Playing position   NaN   NaN  Content with training overall
# 15  ST (C) - Playing position   NaN   NaN  Content with training overall
# 16   D (C) - Playing position   NaN   NaN  Content with training overall
# 17   D (L) - Playing position   NaN   NaN  Content with training overall
# 18  AM (R) - Playing position   NaN   NaN  Content with training overall
# 19  ST (C) - Playing position   NaN   NaN  Content with training overall
# 20   M (C) - Playing position   NaN   NaN  Content with training overall
# 21      GK - Playing position   NaN   NaN  Content with training overall
# 22                        NaN   NaN   NaN                              -
# 23   D (C) - Playing position   NaN   NaN  Content with training overall
# 24                        NaN   NaN   NaN                              -
# 25  AM (R) - Playing position   NaN   NaN  Content with training overall
# 26   M (C) - Playing position   NaN   NaN  Content with training overall
# 27  AM (L) - Playing position   NaN   NaN  Content with training overall
# 28                        NaN   NaN   NaN                              -
# 29   D (C) - Playing position   NaN   NaN  Content with training overall
#
#    Training Happiness Details Training Intensity
# 0                         NaN   Normal Intensity
# 1                         NaN   Normal Intensity
# 2                         NaN   Normal Intensity
# 3                         NaN   Normal Intensity
# 4                         NaN   Normal Intensity
# 5                         NaN   Normal Intensity
# 6                         NaN   Normal Intensity
# 7                         NaN   Normal Intensity
# 8                         NaN   Normal Intensity
# 9                         NaN   Normal Intensity
# 10                        NaN   Normal Intensity
# 11                        NaN   Normal Intensity
# 12                        NaN   Normal Intensity
# 13                        NaN   Normal Intensity
# 14                        NaN   Normal Intensity
# 15                        NaN                NaN
# 16                        NaN   Normal Intensity
# 17                        NaN   Normal Intensity
# 18                        NaN   Normal Intensity
# 19                    Injured                NaN
# 20                        NaN   Normal Intensity
# 21                        NaN   Normal Intensity
# 22                          -                NaN
# 23                        NaN   Normal Intensity
# 24                          -                NaN
# 25                        NaN   Normal Intensity
# 26                        NaN   Normal Intensity
# 27                        NaN   Normal Intensity
# 28                          -                NaN
# 29                    Injured                NaN

# %%
for col in df.columns:
    print("{}: {}".format(col,df[col].dtype))
# Out:
# UID: int64
# Trn Rat: object
# Workload: object
# Focus: object
# AtTa: float64
# DeTe: float64
# Fit: float64
# GKH: float64
# GKS: bool
# Level: object
# Performance: float64
# Physio Recommendation: object
# New Player Trait: float64
# Position/Role/Duty: object
# PoTa: float64
# PoTe: float64
# Training Happiness: object
# Training Happiness Details: object
# Training Intensity: object

# %%
#changing the 'GKS' column data type from bool to object
df['GKS'] = df['GKS'].astype('object')

print(df.dtypes)
# Out:
# UID                             int64
# Trn Rat                        object
# Workload                       object
# Focus                          object
# AtTa                          float64
# DeTe                          float64
# Fit                           float64
# GKH                           float64
# GKS                            object
# Level                          object
# Performance                   float64
# Physio Recommendation          object
# New Player Trait              float64
# Position/Role/Duty             object
# PoTa                          float64
# PoTe                          float64
# Training Happiness             object
# Training Happiness Details     object
# Training Intensity             object
# dtype: object
